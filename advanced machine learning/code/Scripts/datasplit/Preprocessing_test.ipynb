# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from preprocessing import get_processed_data

# %%
df = get_processed_data("../../Dataset/creditcard.csv")

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -2.222530e-16  2.414977e-16  9.373075e-16  1.983986e-15  6.776134e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.879850e+01 -4.403521e+01 -3.187168e+01 -4.013912e+00 -8.240795e+01
# 25%   -4.698909e-01 -3.624701e-01 -5.872131e-01 -5.993777e-01 -5.010677e-01
# 50%    9.245335e-03  3.965677e-02  1.186122e-01 -1.401721e-02 -3.936675e-02
# 75%    6.716927e-01  4.867194e-01  6.774557e-01  5.250073e-01  4.433457e-01
# max    1.253349e+00  1.335773e+01  6.187982e+00  1.191872e+01  2.521409e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.154883e-15  3.136435e-16  7.814893e-17 -1.921447e-15  2.030036e-15
# ...

# %%
clean = df[df['Class'] == 0]
fraud = df[df['Class'] == 1]

clean = clean.reset_index(drop=True)
fraud = fraud.reset_index(drop=True)

# %%
fig,ax = plt.subplots()

clean['LogAmount'].plot.hist(bins=100, logy=True, ax=ax)
fraud['LogAmount'].plot.hist(bins=20, logy=True, ax=ax)

ax.set(xlabel='Normalized log withdrawn amount')

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 5))
#df['TimeComponent1'].plot(c='g', ax=axs[0])
#df['TimeComponent2'].plot(c='g', ax=axs[0])
axs[0].plot(np.linspace(0,4*np.pi), np.sin(np.linspace(0,4*np.pi)), c='g')
axs[0].plot(np.linspace(0,4*np.pi), np.cos(np.linspace(0,4*np.pi)), c='g')

clean['TimeComponent1'].plot(c='b', ax=axs[1])
clean['TimeComponent2'].plot(c='b', ax=axs[1])

fraud['TimeComponent1'].plot(c='orange')
fraud['TimeComponent2'].plot(c='orange')

# %%
clean.plot.scatter(x='TimeComponent1', y='TimeComponent2')
fraud.plot.scatter(x='TimeComponent1', y='TimeComponent2', c='orange')
